# %%
from pyspark.sql import SparkSession
import time

# Creamos la sesión conectada al Master
spark = SparkSession.builder \
    .appName("Prueba_Tour_Spark") \
    .master("spark://spark-master:7077") \
    .getOrCreate()

print("¡Sesión Iniciada! Revisa el Master UI.")

# Dormimos el programa 5 minutos para que te de tiempo de ver las otras webs
time.sleep(300)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/17 00:30:04 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# ¡Sesión Iniciada! Revisa el Master UI.
# 26/01/17 00:30:25 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
# %% [markdown]
# # 1. Ingesta (Capa Bronce)
# Convertimos CSV crudo a formato Delta Lake.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, to_date
from delta import *
import os

# URL del Master (definida en docker-compose)
master_url = "spark://spark-master:7077"

# Configuración: Añadimos Delta Lake
builder = SparkSession.builder \
    .appName("Lab_SECOP_Bronze") \
    .master(master_url) \
    .config("spark.jars.packages", "io.delta:delta-spark_2.12:3.0.0") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .config("spark.executor.memory", "1g") 

spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
# LECTURA CSV
print("Leyendo CSV crudo...")
df_raw = spark.read \
    .format("csv") \
    .option("header", "true") \
    .option("delimiter", ",") \
    .option("inferSchema", "true") \
    .load("../data/SECOP_II_Contratos_Electronicos.csv")
# Out:
# Leyendo CSV crudo...

# %%
df_raw.show()
# Out:
# [Stage 4:>                                                          (0 + 1) / 1]
# +--------------+-----------+------------+------+------+-----------------------+----------------+-------------------------+---------------------------------------+--------------+----------------------------+-------------------------+-----------+-----------+------------+
# |       Entidad|Nit Entidad|Departamento|Ciudad|Estado|Descripcion del Proceso|Tipo de Contrato|Modalidad de Contratacion|Justificacion Modalidad de Contratacion|Fecha de Firma|Fecha de Inicio del Contrato|Fecha de Fin del Contrato|Precio Base|Valor Total|Valor Pagado|
# +--------------+-----------+------------+------+------+-----------------------+----------------+-------------------------+---------------------------------------+--------------+----------------------------+-------------------------+-----------+-----------+------------+
# |   ALCALDIA 90|       NULL|     BOLIVAR|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-02-28|                        NULL|                     NULL|    3582652|       NULL|        NULL|
# |   ALCALDIA 78|       NULL|CUNDINAMARCA|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-05-09|                        NULL|                     NULL| 2745675528|       NULL|        NULL|
# |   HOSPITAL 23|       NULL|   ATLANTICO|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-02-23|                        NULL|                     NULL| 3704121732|       NULL|        NULL|
# |UNIVERSIDAD 87|       NULL|   ANTIOQUIA|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-11-13|                        NULL|                     NULL| 1993838284|       NULL|        NULL|
# |  INSTITUTO 61|       NULL|CUNDINAMARCA|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-09-30|                        NULL|                     NULL| 4437422507|       NULL|        NULL|
# |UNIVERSIDAD 38|       NULL|CUNDINAMARCA|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-05-11|                        NULL|                     NULL| 3017097008|       NULL|        NULL|
# |GOBERNACION 17|       NULL|   ATLANTICO|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-05-29|                        NULL|                     NULL| 2613897233|       NULL|        NULL|
# |   ALCALDIA 43|       NULL|       VALLE|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-11-20|                        NULL|                     NULL| 3453566058|       NULL|        NULL|
# |UNIVERSIDAD 99|       NULL|       VALLE|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-09-04|                        NULL|                     NULL| 4984235025|       NULL|        NULL|
# |   ALCALDIA 51|       NULL|   ATLANTICO|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-12-19|                        NULL|                     NULL|  597975492|       NULL|        NULL|
# |   HOSPITAL 22|       NULL|   ATLANTICO|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-03-18|                        NULL|                     NULL| 4036222522|       NULL|        NULL|
# |  INSTITUTO 90|       NULL|   SANTANDER|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-12-20|                        NULL|                     NULL| 4841926763|       NULL|        NULL|
# |GOBERNACION 49|       NULL|   SANTANDER|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-07-01|                        NULL|                     NULL| 4535776652|       NULL|        NULL|
# |  INSTITUTO 83|       NULL|      BOGOTA|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-05-03|                        NULL|                     NULL| 3210059135|       NULL|        NULL|
# |UNIVERSIDAD 10|       NULL|     BOLIVAR|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-03-21|                        NULL|                     NULL|  122886186|       NULL|        NULL|
# |GOBERNACION 36|       NULL|   SANTANDER|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-10-29|                        NULL|                     NULL|  492321103|       NULL|        NULL|
# | INSTITUTO 100|       NULL|       VALLE|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-04-30|                        NULL|                     NULL| 3658679296|       NULL|        NULL|
# |UNIVERSIDAD 26|       NULL|       VALLE|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-06-08|                        NULL|                     NULL| 4443023803|       NULL|        NULL|
# |GOBERNACION 23|       NULL|     BOLIVAR|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-02-19|                        NULL|                     NULL| 3837055500|       NULL|        NULL|
# |   HOSPITAL 38|       NULL|   SANTANDER|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-03-30|                        NULL|                     NULL| 2495852887|       NULL|        NULL|
# +--------------+-----------+------------+------+------+-----------------------+----------------+-------------------------+---------------------------------------+--------------+----------------------------+-------------------------+-----------+-----------+------------+
# only showing top 20 rows

# %%
nuevas_columnas= [

    c.strip().replace(" ", "_").replace("(", "").replace(")", "").lower() 
for c in df_raw.columns

]


# Aplicamos los nuevos nombres al DataFrame
df_raw = df_raw.toDF(*nuevas_columnas)
 
print("Nuevas columnas:", df_raw.columns)
# Out:
# Nuevas columnas: ['entidad', 'nit_entidad', 'departamento', 'ciudad', 'estado', 'descripcion_del_proceso', 'tipo_de_contrato', 'modalidad_de_contratacion', 'justificacion_modalidad_de_contratacion', 'fecha_de_firma', 'fecha_de_inicio_del_contrato', 'fecha_de_fin_del_contrato', 'precio_base', 'valor_total', 'valor_pagado']

# %%
# %%
# ESCRITURA BRONCE (Delta)
print("Escribiendo en capa Bronce...")
output_path = "../data/lakehouse/bronze/secop"
df_raw.write.format("delta").mode("overwrite").save(output_path)

print(f"Ingesta completada. Registros procesados: {df_raw.count()}")
# Out:
# Escribiendo en capa Bronce...
# 26/01/17 00:59:26 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Ingesta completada. Registros procesados: 1000

# %%
delta_secop = "/app/data/lakehouse/bronze/secop"
spark.sql(f"DESCRIBE HISTORY delta.`{delta_secop}`").show()
# Out:
# +-------+--------------------+------+--------+---------+--------------------+----+--------+---------+-----------+--------------+-------------+--------------------+------------+--------------------+
# |version|           timestamp|userId|userName|operation| operationParameters| job|notebook|clusterId|readVersion|isolationLevel|isBlindAppend|    operationMetrics|userMetadata|          engineInfo|
# +-------+--------------------+------+--------+---------+--------------------+----+--------+---------+-----------+--------------+-------------+--------------------+------------+--------------------+
# |      0|2026-01-17 00:59:...|  NULL|    NULL|    WRITE|{mode -> Overwrit...|NULL|    NULL|     NULL|       NULL|  Serializable|        false|{numFiles -> 1, n...|        NULL|Apache-Spark/3.5....|
# +-------+--------------------+------+--------+---------+--------------------+----+--------+---------+-----------+--------------+-------------+--------------------+------------+--------------------+

# %% [markdown]
# Transformación: (Ej: filter, select) Spark solo planea. Es instantáneo.
# Acción: (Ej: show, count, save) Aquí es donde Spark realmente trabaja.
# Por qué importa: Si tu código da error, a menudo el error salta en la última línea (show), aunque el problema esté al principio.

# %%
df_raw.printSchema()
# Out:
# root
#  |-- entidad: string (nullable = true)
#  |-- nit_entidad: string (nullable = true)
#  |-- departamento: string (nullable = true)
#  |-- ciudad: string (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- descripcion_del_proceso: string (nullable = true)
#  |-- tipo_de_contrato: string (nullable = true)
#  |-- modalidad_de_contratacion: string (nullable = true)
#  |-- justificacion_modalidad_de_contratacion: string (nullable = true)
#  |-- fecha_de_firma: date (nullable = true)
#  |-- fecha_de_inicio_del_contrato: string (nullable = true)
#  |-- fecha_de_fin_del_contrato: string (nullable = true)
#  |-- precio_base: long (nullable = true)
#  |-- valor_total: string (nullable = true)
#  |-- valor_pagado: string (nullable = true)

# %%
df_raw.show(5,vertical=True)
# Out:
# -RECORD 0-------------------------------------------------
#  entidad                                 | ALCALDIA 90
#  nit_entidad                             | NULL
#  departamento                            | BOLIVAR
#  ciudad                                  | NULL
#  estado                                  | NULL
#  descripcion_del_proceso                 | NULL
#  tipo_de_contrato                        | NULL
#  modalidad_de_contratacion               | NULL
#  justificacion_modalidad_de_contratacion | NULL
#  fecha_de_firma                          | 2023-02-28
#  fecha_de_inicio_del_contrato            | NULL
#  fecha_de_fin_del_contrato               | NULL
#  precio_base                             | 3582652
#  valor_total                             | NULL
#  valor_pagado                            | NULL
# -RECORD 1-------------------------------------------------
#  entidad                                 | ALCALDIA 78
#  nit_entidad                             | NULL
#  departamento                            | CUNDINAMARCA
#  ciudad                                  | NULL
#  estado                                  | NULL
#  descripcion_del_proceso                 | NULL
#  tipo_de_contrato                        | NULL
#  modalidad_de_contratacion               | NULL
#  justificacion_modalidad_de_contratacion | NULL
#  fecha_de_firma                          | 2023-05-09
#  fecha_de_inicio_del_contrato            | NULL
#  fecha_de_fin_del_contrato               | NULL
#  precio_base                             | 2745675528
#  valor_total                             | NULL
#  valor_pagado                            | NULL
# -RECORD 2-------------------------------------------------
#  entidad                                 | HOSPITAL 23
#  nit_entidad                             | NULL
#  departamento                            | ATLANTICO
#  ciudad                                  | NULL
#  estado                                  | NULL
#  descripcion_del_proceso                 | NULL
#  tipo_de_contrato                        | NULL
#  modalidad_de_contratacion               | NULL
#  justificacion_modalidad_de_contratacion | NULL
#  fecha_de_firma                          | 2023-02-23
#  fecha_de_inicio_del_contrato            | NULL
#  fecha_de_fin_del_contrato               | NULL
#  precio_base                             | 3704121732
#  valor_total                             | NULL
#  valor_pagado                            | NULL
# -RECORD 3-------------------------------------------------
#  entidad                                 | UNIVERSIDAD 87
#  nit_entidad                             | NULL
#  departamento                            | ANTIOQUIA
#  ciudad                                  | NULL
#  estado                                  | NULL
#  descripcion_del_proceso                 | NULL
#  tipo_de_contrato                        | NULL
#  modalidad_de_contratacion               | NULL
#  justificacion_modalidad_de_contratacion | NULL
#  fecha_de_firma                          | 2023-11-13
#  fecha_de_inicio_del_contrato            | NULL
#  fecha_de_fin_del_contrato               | NULL
#  precio_base                             | 1993838284
#  valor_total                             | NULL
#  valor_pagado                            | NULL
# -RECORD 4-------------------------------------------------
#  entidad                                 | INSTITUTO 61
#  nit_entidad                             | NULL
#  departamento                            | CUNDINAMARCA
#  ciudad                                  | NULL
#  estado                                  | NULL
#  descripcion_del_proceso                 | NULL
#  tipo_de_contrato                        | NULL
#  modalidad_de_contratacion               | NULL
#  justificacion_modalidad_de_contratacion | NULL
#  fecha_de_firma                          | 2023-09-30
#  fecha_de_inicio_del_contrato            | NULL
#  fecha_de_fin_del_contrato               | NULL
#  precio_base                             | 4437422507
#  valor_total                             | NULL
#  valor_pagado                            | NULL
# only showing top 5 rows

# %%
df_raw.count()
# Out:
# 1000

# %%
df_raw.columns
# Out:
# ['entidad',
#  'nit_entidad',
#  'departamento',
#  'ciudad',
#  'estado',
#  'descripcion_del_proceso',
#  'tipo_de_contrato',
#  'modalidad_de_contratacion',
#  'justificacion_modalidad_de_contratacion',
#  'fecha_de_firma',
#  'fecha_de_inicio_del_contrato',
#  'fecha_de_fin_del_contrato',
#  'precio_base',
#  'valor_total',
#  'valor_pagado']

# %% [markdown]
# 2. Seleccionar y Filtrar (El "Bisturí")
# Recortar los datos a lo que necesitas.
# Python

# %%
# Seleccionar columnas específicas
df_nuevo = df_raw.select("entidad", "nit_entidad", "precio_base")
df_nuevo.show(5)
# Filtrar (WHERE)# Opción A (Estilo SQL):
df_filtrado = df_raw.filter("precio_base > 100000 ")
df_filtrado.count()
# Opción B (Estilo Pythonico - Recomendado
df_filtrado = df_raw.filter((col("edad") > 18) & (col("ciudad") == "Bogota"))
# Out:
# +--------------+-----------+-----------+
# |       entidad|nit_entidad|precio_base|
# +--------------+-----------+-----------+
# |   ALCALDIA 90|       NULL|    3582652|
# |   ALCALDIA 78|       NULL| 2745675528|
# |   HOSPITAL 23|       NULL| 3704121732|
# |UNIVERSIDAD 87|       NULL| 1993838284|
# |  INSTITUTO 61|       NULL| 4437422507|
# +--------------+-----------+-----------+
# only showing top 5 rows
# 1000

# %%
# Crear una columna nueva (o reemplazar una existente)# Ejemplo: Crear columna 'edad_doble'
df_mod = df_raw.withColumn("precio_base_doble", col("precio_base") * 2)
df_mod.show()
# Out:
# +--------------+-----------+------------+------+------+-----------------------+----------------+-------------------------+---------------------------------------+--------------+----------------------------+-------------------------+-----------+-----------+------------+-----------------+
# |       entidad|nit_entidad|departamento|ciudad|estado|descripcion_del_proceso|tipo_de_contrato|modalidad_de_contratacion|justificacion_modalidad_de_contratacion|fecha_de_firma|fecha_de_inicio_del_contrato|fecha_de_fin_del_contrato|precio_base|valor_total|valor_pagado|precio_base_doble|
# +--------------+-----------+------------+------+------+-----------------------+----------------+-------------------------+---------------------------------------+--------------+----------------------------+-------------------------+-----------+-----------+------------+-----------------+
# |   ALCALDIA 90|       NULL|     BOLIVAR|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-02-28|                        NULL|                     NULL|    3582652|       NULL|        NULL|          7165304|
# |   ALCALDIA 78|       NULL|CUNDINAMARCA|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-05-09|                        NULL|                     NULL| 2745675528|       NULL|        NULL|       5491351056|
# |   HOSPITAL 23|       NULL|   ATLANTICO|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-02-23|                        NULL|                     NULL| 3704121732|       NULL|        NULL|       7408243464|
# |UNIVERSIDAD 87|       NULL|   ANTIOQUIA|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-11-13|                        NULL|                     NULL| 1993838284|       NULL|        NULL|       3987676568|
# |  INSTITUTO 61|       NULL|CUNDINAMARCA|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-09-30|                        NULL|                     NULL| 4437422507|       NULL|        NULL|       8874845014|
# |UNIVERSIDAD 38|       NULL|CUNDINAMARCA|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-05-11|                        NULL|                     NULL| 3017097008|       NULL|        NULL|       6034194016|
# |GOBERNACION 17|       NULL|   ATLANTICO|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-05-29|                        NULL|                     NULL| 2613897233|       NULL|        NULL|       5227794466|
# |   ALCALDIA 43|       NULL|       VALLE|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-11-20|                        NULL|                     NULL| 3453566058|       NULL|        NULL|       6907132116|
# |UNIVERSIDAD 99|       NULL|       VALLE|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-09-04|                        NULL|                     NULL| 4984235025|       NULL|        NULL|       9968470050|
# |   ALCALDIA 51|       NULL|   ATLANTICO|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-12-19|                        NULL|                     NULL|  597975492|       NULL|        NULL|       1195950984|
# |   HOSPITAL 22|       NULL|   ATLANTICO|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-03-18|                        NULL|                     NULL| 4036222522|       NULL|        NULL|       8072445044|
# |  INSTITUTO 90|       NULL|   SANTANDER|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-12-20|                        NULL|                     NULL| 4841926763|       NULL|        NULL|       9683853526|
# |GOBERNACION 49|       NULL|   SANTANDER|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-07-01|                        NULL|                     NULL| 4535776652|       NULL|        NULL|       9071553304|
# |  INSTITUTO 83|       NULL|      BOGOTA|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-05-03|                        NULL|                     NULL| 3210059135|       NULL|        NULL|       6420118270|
# |UNIVERSIDAD 10|       NULL|     BOLIVAR|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-03-21|                        NULL|                     NULL|  122886186|       NULL|        NULL|        245772372|
# |GOBERNACION 36|       NULL|   SANTANDER|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-10-29|                        NULL|                     NULL|  492321103|       NULL|        NULL|        984642206|
# | INSTITUTO 100|       NULL|       VALLE|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-04-30|                        NULL|                     NULL| 3658679296|       NULL|        NULL|       7317358592|
# |UNIVERSIDAD 26|       NULL|       VALLE|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-06-08|                        NULL|                     NULL| 4443023803|       NULL|        NULL|       8886047606|
# |GOBERNACION 23|       NULL|     BOLIVAR|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-02-19|                        NULL|                     NULL| 3837055500|       NULL|        NULL|       7674111000|
# |   HOSPITAL 38|       NULL|   SANTANDER|  NULL|  NULL|                   NULL|            NULL|                     NULL|                                   NULL|    2023-03-30|                        NULL|                     NULL| 2495852887|       NULL|        NULL|       4991705774|
# +--------------+-----------+------------+------+------+-----------------------+----------------+-------------------------+---------------------------------------+--------------+----------------------------+-------------------------+-----------+-----------+------------+-----------------+
# only showing top 20 rows

# %%
# Renombrar columna
df_renom = df.withColumnRenamed("nombre_viejo", "nombre_nuevo")
# Borrar columna
df_menos =df.drop("columna_innecesaria")
# Condicionales (CASE WHEN)
df_cat = df.withColumn("categoria", 
             when(col("edad") < 18, "Menor")
             .when(col("edad") >= 65, "Jubilado")
             .otherwise("Adulto")
         )

# %%
help(sum)
# Out:
# Help on built-in function sum in module builtins:
#
# sum(iterable, /, start=0)
#     Return the sum of a 'start' value (default: 0) plus an iterable of numbers
#
#     When the iterable is empty, return the start value.
#     This function is intended specifically for use with numeric values and may
#     reject non-numeric types.

# %%
# Agrupar por ciudad y sumar salarios
from pyspark.sql.functions import sum, avg, count, col
 
 

df_resumen = df_raw.groupBy("ciudad") \
               .agg(                   sum("precio_base").alias("inversion_total"),
                   avg("precio_base").alias("promedio_precio_base"),
                   count("*").alias("cantidad")
               )
    
df_resumen.show()
# Out:
# +------+---------------+--------------------+--------+
# |ciudad|inversion_total|promedio_precio_base|cantidad|
# +------+---------------+--------------------+--------+
# |  NULL|  2565343069588|    2.565343069588E9|    1000|
# +------+---------------+--------------------+--------+

# %%
df_raw.printSchema()
# Out:
# root
#  |-- entidad: string (nullable = true)
#  |-- nit_entidad: string (nullable = true)
#  |-- departamento: string (nullable = true)
#  |-- ciudad: string (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- descripcion_del_proceso: string (nullable = true)
#  |-- tipo_de_contrato: string (nullable = true)
#  |-- modalidad_de_contratacion: string (nullable = true)
#  |-- justificacion_modalidad_de_contratacion: string (nullable = true)
#  |-- fecha_de_firma: date (nullable = true)
#  |-- fecha_de_inicio_del_contrato: string (nullable = true)
#  |-- fecha_de_fin_del_contrato: string (nullable = true)
#  |-- precio_base: long (nullable = true)
#  |-- valor_total: string (nullable = true)
#  |-- valor_pagado: string (nullable = true)

# %%
# 1. Registras el DataFrame como una "tabla temporal" (vista)

df_raw.createOrReplaceTempView("temporal_tabla")



# 2. Escribes SQL puro

df_sql = spark.sql("""

    SELECT ciudad, avg(precio_base) as precio_base_promedio

    FROM temporal_tabla

    GROUP BY ciudad

""")



df_sql.show()
# Out:
# +------+--------------------+
# |ciudad|precio_base_promedio|
# +------+--------------------+
# |  NULL|    2.565343069588E9|
# +------+--------------------+
